# %%
#tuple
tuple_life=('ezekiel', 'edidiong', 'etiene')
print(tuple_life)
print(type(tuple_life))
# Out:
# ('ezekiel', 'edidiong', 'etiene')
# <class 'tuple'>

# %%
#list
list_life=['wisdom','okubre', 'victor']
print(list_life)
# Out:
# ['wisdom', 'okubre', 'victor']

# %%
#switching a tuple to list
list_life=list(tuple_life)
print(list_life)
print(type(list_life))
# Out:
# ['ezekiel', 'edidiong', 'etiene']
# <class 'list'>

# %%
#switching a list to tuple
tuple_life=tuple(list_life)
print(tuple_life)
print(type(tuple_life))
# Out:
# ('ezekiel', 'edidiong', 'etiene')
# <class 'tuple'>

# %%
# 1.assigning a variable
name='lifepraize'
print(name)
# Out:
# lifepraize

# %%
# 3. string sentence variable
string_variable='sentence'
print=(string_variable)

# %%
#tuple of my favorite book
favorite_book=("The Amazon of witchcraft", "1984","Orphans in tears")
print("my favorite books are:", favorite_book)
# Out:
# my favorite books are: ('The Amazon of witchcraft', '1984', 'Orphans in tears')

# %%
a=[1,2,3,4]
a[2:-1]
# Out:
# [3]

# %%
#pallidrone
a='caleb'
x=a[::-1]
if a==x:
    print('yes')
else:
     print('no')
# Out:
# no

# %%
#assigning variable
a=10
name='victor'
salary=2000.23
print(a)
print(name)
print(salary)
# Out:
# 10
# victor
# 2000.23

# %%
#multiple assignment
a=10
b=10
c=10
a=b=c=10
x=20
y=30
z=40
x,y,z=20,30,40
print(y,a)
# Out:
# 30 10

# %%
#python token is a small meaningfull component orvery basic component of a sourcecode
#token can be keyword,literal,identifier,or operator

# %%
#examples of literals
val1=10
val2=None
val1
10
val2
print(val2)
print(val1)
# Out:
# None
# 10

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Social_Network_Ads.csv",sep=",")

# %%
data.head(10)
# Out:
#     Age  EstimatedSalary  Purchased
# 0  19.0          19000.0        0.0
# 1  35.0          20000.0        0.0
# 2  26.0          43000.0        0.0
# 3  27.0          57000.0        0.0
# 4  19.0          76000.0        0.0
# 5  27.0          58000.0        0.0
# 6  27.0          84000.0        0.0
# 7  32.0              NaN        1.0
# 8  25.0          33000.0        0.0
# 9  35.0          65000.0        0.0

# %%
data.describe()
# Out:
#               Age  EstimatedSalary   Purchased
# count  398.000000       397.000000  396.000000
# mean    37.680905     69609.571788    0.356061
# std     10.492708     33887.085366    0.479439
# min     18.000000     15000.000000    0.000000
# 25%     30.000000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     87000.000000    1.000000
# max     60.000000    150000.000000    1.000000

# %%
data.drop('Purchased',axis=1)
# Out:
#       Age  EstimatedSalary
# 0    19.0          19000.0
# 1    35.0          20000.0
# 2    26.0          43000.0
# 3    27.0          57000.0
# 4    19.0          76000.0
# ..    ...              ...
# 395  46.0          41000.0
# 396  51.0          23000.0
# 397  50.0          20000.0
# 398  36.0          33000.0
# 399  49.0          36000.0
#
# [400 rows x 2 columns]

# %%
data.drop('Age', axis=1)
# Out:
#      EstimatedSalary  Purchased
# 0            19000.0        0.0
# 1            20000.0        0.0
# 2            43000.0        0.0
# 3            57000.0        0.0
# 4            76000.0        0.0
# ..               ...        ...
# 395          41000.0        1.0
# 396          23000.0        1.0
# 397          20000.0        1.0
# 398          33000.0        0.0
# 399          36000.0        1.0
#
# [400 rows x 2 columns]

# %%
data.shape
# Out:
# (400, 3)

# %%
data[['Purchased', 'EstimatedSalary']]
# Out:
#      Purchased  EstimatedSalary
# 0          0.0          19000.0
# 1          0.0          20000.0
# 2          0.0          43000.0
# 3          0.0          57000.0
# 4          0.0          76000.0
# ..         ...              ...
# 395        1.0          41000.0
# 396        1.0          23000.0
# 397        1.0          20000.0
# 398        0.0          33000.0
# 399        1.0          36000.0
#
# [400 rows x 2 columns]

# %%
lifepraise=data[['Purchased','EstimatedSalary']]
lifepraise
# Out:
#      Purchased  EstimatedSalary
# 0          0.0          19000.0
# 1          0.0          20000.0
# 2          0.0          43000.0
# 3          0.0          57000.0
# 4          0.0          76000.0
# ..         ...              ...
# 395        1.0          41000.0
# 396        1.0          23000.0
# 397        1.0          20000.0
# 398        0.0          33000.0
# 399        1.0          36000.0
#
# [400 rows x 2 columns]

# %%
data.iloc[1:400,:-1]
# Out:
#       Age  EstimatedSalary
# 1    35.0          20000.0
# 2    26.0          43000.0
# 3    27.0          57000.0
# 4    19.0          76000.0
# 5    27.0          58000.0
# ..    ...              ...
# 395  46.0          41000.0
# 396  51.0          23000.0
# 397  50.0          20000.0
# 398  36.0          33000.0
# 399  49.0          36000.0
#
# [399 rows x 2 columns]

# %%
data.iloc[2:400,:-2]
# Out:
#       Age
# 2    26.0
# 3    27.0
# 4    19.0
# 5    27.0
# 6    27.0
# ..    ...
# 395  46.0
# 396  51.0
# 397  50.0
# 398  36.0
# 399  49.0
#
# [398 rows x 1 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              398 non-null    float64
#  1   EstimatedSalary  397 non-null    float64
#  2   Purchased        396 non-null    float64
# dtypes: float64(3)
# memory usage: 9.5 KB

# %%
data[data['Age']<30]
tenage=data[data['Age']<30]

# %%
#age less than 30d
tenage=data[data['Age']<30]
print(tenage)
# Out:
#       Age  EstimatedSalary  Purchased
# 0    19.0          19000.0        0.0
# 2    26.0          43000.0        0.0
# 3    27.0          57000.0        0.0
# 4    19.0          76000.0        0.0
# 5    27.0          58000.0        0.0
# ..    ...              ...        ...
# 192  29.0          43000.0        0.0
# 193  19.0          70000.0        0.0
# 194  28.0          89000.0        0.0
# 197  20.0          36000.0        0.0
# 198  26.0          80000.0        0.0
#
# [99 rows x 3 columns]

# %%
#age greater than 30
data[data['Age']>=30]
# Out:
#       Age  EstimatedSalary  Purchased
# 1    35.0          20000.0        0.0
# 7    32.0              NaN        1.0
# 9    35.0          65000.0        0.0
# 13   32.0          18000.0        0.0
# 16   47.0          25000.0        1.0
# ..    ...              ...        ...
# 395  46.0          41000.0        1.0
# 396  51.0          23000.0        1.0
# 397  50.0          20000.0        1.0
# 398  36.0          33000.0        0.0
# 399  49.0          36000.0        1.0
#
# [299 rows x 3 columns]

# %%
data[data['Age']==30]
#comparism of people that are 30yrs of age
# Out:
#       Age  EstimatedSalary  Purchased
# 37   30.0          49000.0        0.0
# 43   30.0          15000.0        0.0
# 48   30.0         135000.0        1.0
# 80   30.0          80000.0        0.0
# 84   30.0          62000.0        0.0
# 91   30.0         116000.0        0.0
# 128  30.0          17000.0        0.0
# 132  30.0          87000.0        0.0
# 137  30.0         107000.0        1.0
# 143  30.0          89000.0        0.0
# 196  30.0          79000.0        0.0

# %%
#age below 30
below_30=data['Age']<30
data[below_30]
# Out:
#       Age  EstimatedSalary  Purchased
# 0    19.0          19000.0        0.0
# 2    26.0          43000.0        0.0
# 3    27.0          57000.0        0.0
# 4    19.0          76000.0        0.0
# 5    27.0          58000.0        0.0
# ..    ...              ...        ...
# 192  29.0          43000.0        0.0
# 193  19.0          70000.0        0.0
# 194  28.0          89000.0        0.0
# 197  20.0          36000.0        0.0
# 198  26.0          80000.0        0.0
#
# [99 rows x 3 columns]

# %%
#age not below 30
below_30=data['Age']<30
data[~below_30]
# Out:
#       Age  EstimatedSalary  Purchased
# 1    35.0          20000.0        0.0
# 7    32.0              NaN        1.0
# 9    35.0          65000.0        0.0
# 13   32.0          18000.0        0.0
# 16   47.0          25000.0        1.0
# ..    ...              ...        ...
# 395  46.0          41000.0        1.0
# 396  51.0          23000.0        1.0
# 397  50.0          20000.0        1.0
# 398  36.0          33000.0        0.0
# 399  49.0          36000.0        1.0
#
# [301 rows x 3 columns]

# %%
#PURCHASED NOT DEFINED
not_purchased=data['Purchased']==0
purchased, not_purchased=data[~not_purchased],data[not_purchased]
purchased.describe()
# Out:
#               Age  EstimatedSalary  Purchased
# count  145.000000       143.000000      141.0
# mean    46.234483     85888.111888        1.0
# std      8.655453     41537.714900        0.0
# min     27.000000     20000.000000        1.0
# 25%     39.000000     41500.000000        1.0
# 50%     47.000000     90000.000000        1.0
# 75%     53.000000    122000.000000        1.0
# max     60.000000    150000.000000        1.0

# %%
#PURCHASED DEFINED
not_purchased.describe()
# Out:
#               Age  EstimatedSalary  Purchased
# count  253.000000       254.000000      255.0
# mean    32.778656     60444.881890        0.0
# std      8.025654     24390.493219        0.0
# min     18.000000     15000.000000        0.0
# 25%     26.000000     44000.000000        0.0
# 50%     34.000000     61000.000000        0.0
# 75%     38.000000     77000.000000        0.0
# max     59.000000    141000.000000        0.0

# %%
#unique values gives unique values present
data['Purchased'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
#nunique gives the number of unique values present
data['Purchased'].nunique()
# Out:
# 2

# %%
#what make them not to purchased, could it salary?
not_purchased
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 #what make them not to purchased, could it salary?
# ----> 2 not_purchased
#
# NameError: name 'not_purchased' is not defined

# %%
not_purchased[not_purchased['EstimatedSalary']==max(not_purchased['EstimatedSalary'])]
# Out:
#       Age  EstimatedSalary  Purchased
# 284  48.0         141000.0        0.0

# %%
not_purchased
# Out:
#       Age  EstimatedSalary  Purchased
# 0    19.0          19000.0        0.0
# 1    35.0          20000.0        0.0
# 2    26.0          43000.0        0.0
# 3    27.0          57000.0        0.0
# 4    19.0          76000.0        0.0
# ..    ...              ...        ...
# 377  42.0          53000.0        0.0
# 380  42.0          64000.0        0.0
# 387  39.0          71000.0        0.0
# 394  39.0          59000.0        0.0
# 398  36.0          33000.0        0.0
#
# [255 rows x 3 columns]

# %%
data.isnull().sum()
# Out:
# Age                2
# EstimatedSalary    3
# Purchased          4
# dtype: int64

# %%
data.Purchased==1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 395     True
# 396     True
# 397     True
# 398    False
# 399     True
# Name: Purchased, Length: 400, dtype: bool

# %%
#true
data[data.Purchased==1]
# Out:
#       Age  EstimatedSalary  Purchased
# 7    32.0              NaN        1.0
# 16   47.0          25000.0        1.0
# 17   45.0          26000.0        1.0
# 18   46.0          28000.0        1.0
# 19   48.0          29000.0        1.0
# ..    ...              ...        ...
# 393  60.0          42000.0        1.0
# 395  46.0          41000.0        1.0
# 396  51.0          23000.0        1.0
# 397  50.0          20000.0        1.0
# 399  49.0          36000.0        1.0
#
# [141 rows x 3 columns]

# %%
#false
data[data.Purchased==0]
# Out:
#       Age  EstimatedSalary  Purchased
# 0    19.0          19000.0        0.0
# 1    35.0          20000.0        0.0
# 2    26.0          43000.0        0.0
# 3    27.0          57000.0        0.0
# 4    19.0          76000.0        0.0
# ..    ...              ...        ...
# 377  42.0          53000.0        0.0
# 380  42.0          64000.0        0.0
# 387  39.0          71000.0        0.0
# 394  39.0          59000.0        0.0
# 398  36.0          33000.0        0.0
#
# [255 rows x 3 columns]

# %%
#checking a true values in data non_purchased
data[data.Purchased==1]
x=data.Purchased==1
~x
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 395    False
# 396    False
# 397    False
# 398     True
# 399    False
# Name: Purchased, Length: 400, dtype: bool

# %%
#checking for correlation of features
data.corr()
# Out:
#                       Age  EstimatedSalary  Purchased
# Age              1.000000         0.166061   0.626529
# EstimatedSalary  0.166061         1.000000   0.365690
# Purchased        0.626529         0.365690   1.000000

# %%
import seaborn as sns
#colormaps include;viridis,plasma,cividis,inferno,magma,coolworm,YIGnBu,YIOrRd,BuPu,RdBu,
sns.heatmap(data.corr(),annot=True,cmap="cividis");
